# %%
import pandas as pd
from fredapi import Fred
fred = Fred(api_key = 'ad3a6467a91aa3eb3d9d8f3128cda35b')

# %%
interest_rate = fred.get_series('FEDFUNDS')
mortgage_rate = fred.get_series('MORTGAGE30US')
consumption = fred.get_series('PCEC96')
investments = fred.get_series('PNFIC1')
unemployment_rate = fred.get_series('UNRATE')
payrolls = fred.get_series('PAYEMS')
labor_turnover = fred.get_series('JTSJOL')
cpi = fred.get_series('CPIAUCSL')
cepi = fred.get_series('DPCCRV1Q225SBEA')
ppi = fred.get_series('PPIACO')
retail_sales = fred.get_series('MRTSSM44000USS')
personal_income = fred.get_series('PI')
personal_saving = fred.get_series('PMSAVE')
personal_spending = fred.get_series('PCE')
housing_starts = fred.get_series('MSPNHSUS')
gdp = fred.get_series('GDP')
industrial_prod = fred.get_series('INDPRO')
#nfci = fred.get_series('NFCICREDIT') didn't work
money_stock = fred.get_series('M1REAL')
#bank_lending = fred.get_series('TOTLL') didn't work
trade_balance = fred.get_series('BOPGSTB')
exports = fred.get_series('NETEXP')
imports = fred.get_series('IMPGS')
consumer_sentiment = fred.get_series('UMCSENT')
vehicle_sales = fred.get_series('TOTALSA')

# %%
df = pd.concat([interest_rate, consumption, unemployment_rate, payrolls, labor_turnover, cpi, cepi, ppi, retail_sales, personal_income, personal_saving, personal_spending, housing_starts, gdp, industrial_prod, money_stock, trade_balance, exports, imports, consumer_sentiment, vehicle_sales], axis =1)
df.columns = ['interest_rate', 'consumption', 'unemployment_rate', 'payrolls', 'labor_turnover', 'cpi', 'cepi', 'ppi', 'retail_sales', 'personal_income', 'personal_saving', 'personal_spending', 'housing_starts', 'gdp','industrial_prod','money_stock', 'trade_balance', 'exports', 'imports', 'consumer_sentiment', 'vehicle_sales']
df=df.dropna()
df.describe()
# Out:
#        interest_rate   consumption  unemployment_rate       payrolls  \
# count      74.000000     74.000000          74.000000      74.000000
# mean        1.502703  13062.370270           5.933784  142780.648649
# std         1.889461   1659.148707           2.328753    8781.676762
# min         0.050000  11068.000000           3.400000  129802.000000
# 25%         0.110000  11550.500000           4.000000  135978.000000
# 50%         0.335000  12757.300000           5.000000  142226.000000
# 75%         2.370000  14179.850000           7.750000  149886.000000
# max         5.330000  16369.000000          14.800000  159433.000000
#
#        labor_turnover         cpi       cepi         ppi   retail_sales  \
# count       74.000000   74.000000  74.000000   74.000000      74.000000
# mean      5953.432432  248.613027   2.156757  206.528243  420854.270270
# std       2467.762733   32.116156   1.331708   28.065080  101307.917611
# min       2232.000000  203.437000  -0.800000  164.000000  287530.000000
# 25%       3912.500000  225.733750   1.400000  187.550000  336456.000000
# 50%       5695.000000  238.513000   1.800000  200.500000  389218.000000
# 75%       7300.250000  260.021000   2.500000  207.375000  478540.500000
# max      11881.000000  320.321000   6.100000  272.274000  623521.000000
#
#        personal_income  ...  personal_spending  housing_starts           gdp  \
# count        74.000000  ...          74.000000       74.000000     74.000000
# mean      16872.686486  ...       13378.975676   306335.135135  19840.175162
# std        4208.326550  ...        3231.350235    74031.030947   4785.958335
# min       11647.100000  ...        9538.700000   204200.000000  14215.651000
# 25%       13383.450000  ...       10749.425000   240700.000000  15696.324750
# 50%       15727.200000  ...       12436.450000   297700.000000  18618.817500
# 75%       20616.725000  ...       14814.725000   338000.000000  22034.879500
# max       25823.500000  ...       20622.300000   460300.000000  30331.117000
#
#        industrial_prod  money_stock  trade_balance      exports      imports  \
# count        74.000000    74.000000      74.000000    74.000000    74.000000
# mean         98.887441  2547.117568  -52411.905405  -646.653041  2997.479649
# std           4.716405  2423.281260   16045.337042   176.094914   592.119700
# min          84.681200   648.900000 -130273.000000 -1245.141000  1879.461000
# 25%          97.566175   898.875000  -62454.250000  -779.919250  2700.310250
# 50%         100.121400  1323.250000  -46917.500000  -572.253500  2817.722000
# 75%         102.259550  5749.675000  -40702.750000  -517.676250  3170.069000
# max         103.929700  7262.800000  -30473.000000  -358.368000  4511.554000
#
#        consumer_sentiment  vehicle_sales
# count           74.000000      74.000000
# mean            79.005405      15.462716
# std             13.241734       2.360984
# min             51.500000       8.944000
# 25%             68.300000      14.447500
# 50%             77.800000      16.023500
# 75%             90.300000      17.136750
# max            100.700000      18.697000
#
# [8 rows x 21 columns]
