# %%
import pandas as pd
from fredapi import Fred
fred = Fred(api_key = 'ad3a6467a91aa3eb3d9d8f3128cda35b')

# %%
interest_rate = fred.get_series('FEDFUNDS')
mortgage_rate = fred.get_series('MORTGAGE30US')
consumption = fred.get_series('PCEC96')
investments = fred.get_series('PNFIC1')
unemployment_rate = fred.get_series('UNRATE')
payrolls = fred.get_series('PAYEMS')
labor_turnover = fred.get_series('JTSJOL')
cpi = fred.get_series('CPIAUCSL')
cepi = fred.get_series('DPCCRV1Q225SBEA')
ppi = fred.get_series('PPIACO')
inflation = fred.get_series('FPCPITOTLZGUSA')
retail_sales = fred.get_series('MRTSSM44000USS')
personal_income = fred.get_series('PI')
personal_saving = fred.get_series('PMSAVE')
household_saving = fred.get_series('W398RC1A027NBEA')
national_saving = fred.get_series('SNDR')
personal_spending = fred.get_series('PCE')
housing_starts = fred.get_series('MSPNHSUS')

# %%
df = pd.concat([interest_rate, labor_turnover, payrolls, cpi, ppi, retail_sales, personal_income, personal_saving, personal_spending, housing_starts, consumption, unemployment_rate], axis =1)

# %%
df=df.dropna()

# %%
df
# Out:
#               0       1         2        3        4         5        6   \
# 2007-01-01  5.25  4763.0  137472.0  203.437  164.000  320305.0  11647.1
# 2007-02-01  5.26  4699.0  137558.0  204.226  166.800  321434.0  11734.2
# 2007-03-01  5.26  4962.0  137782.0  205.288  169.300  323708.0  11821.4
# 2007-04-01  5.25  4689.0  137845.0  205.904  171.400  322878.0  11868.1
# 2007-05-01  5.25  4657.0  137993.0  206.755  173.300  327266.0  11908.7
# ...          ...     ...       ...      ...      ...       ...      ...
# 2025-02-01  4.33  7480.0  159155.0  319.775  259.498  616714.0  25456.0
# 2025-03-01  4.33  7200.0  159275.0  319.615  258.525  625121.0  25619.3
# 2025-04-01  4.33  7395.0  159433.0  320.321  258.369  623521.0  25823.5
# 2025-05-01  4.33  7712.0  159452.0  320.580  258.606  618037.0  25722.7
# 2025-06-01  4.33  7437.0  159466.0  321.500  260.648  623882.0  25794.1
#
#                 7        8         9        10   11
# 2007-01-01   242.1   9538.7  254400.0  11181.0  4.6
# 2007-02-01   283.0   9566.0  250800.0  11178.2  4.5
# 2007-03-01   313.4   9611.7  262600.0  11190.7  4.4
# 2007-04-01   309.7   9643.6  242500.0  11201.5  4.5
# 2007-05-01   295.0   9685.8  245000.0  11218.0  4.4
# ...            ...      ...       ...      ...  ...
# 2025-02-01   986.2  20436.3  415100.0  16249.6  4.1
# 2025-03-01   985.1  20578.5  412900.0  16360.1  4.2
# 2025-04-01  1126.8  20622.3  413300.0  16369.0  4.2
# 2025-05-01  1016.2  20615.2  422700.0  16336.1  4.2
# 2025-06-01  1007.8  20685.2  401800.0  16345.6  4.1
#
# [222 rows x 12 columns]
